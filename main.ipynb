# %%
from doc_processor import doc_processor_with_descriptions

# %%
# 1) Generate markdown (you already have this working)
pdf_path = "sample.pdf"
output_dir = "doc_assets"
md_path = doc_processor_with_descriptions(pdf_path, output_root=output_dir)
print(f"✅ Finished. Markdown written to: {md_path}")
print("   Folders created: page_images/, image_png_images/, table_images/")
# Out:
# [INFO] 2026-03-12 12:47:09,822 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-12 12:47:09,837 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-03-12 12:47:09,839 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.7.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-12 12:47:12,242 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2026-03-12 12:47:15,862 [RapidOCR] download_file.py:95: Successfully saved to: C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-12 12:47:15,862 [RapidOCR] main.py:50: Using C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-12 12:47:16,166 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-12 12:47:16,168 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-03-12 12:47:16,171 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.7.0/torch/PP-OCRv4/cls/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-12 12:47:19,322 [RapidOCR] download_file.py:82: Download size: 0.56MB
# [INFO] 2026-03-12 12:47:19,549 [RapidOCR] download_file.py:95: Successfully saved to: C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-12 12:47:19,552 [RapidOCR] main.py:50: Using C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-12 12:47:19,652 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-12 12:47:19,657 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-03-12 12:47:19,657 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.7.0/torch/PP-OCRv4/rec/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-03-12 12:47:22,829 [RapidOCR] download_file.py:82: Download size: 25.67MB
# [INFO] 2026-03-12 12:47:29,592 [RapidOCR] download_file.py:95: Successfully saved to: C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-03-12 12:47:29,592 [RapidOCR] main.py:50: Using C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# Processed 11 page(s) from: sample.pdf
# Final markdown written to: doc_assets\processed_doc.md
# ✅ Finished. Markdown written to: doc_assets\processed_doc.md
#    Folders created: page_images/, image_png_images/, table_images/
